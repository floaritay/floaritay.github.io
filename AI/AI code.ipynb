# %% [markdown]
# | 工具名称 | 官网 | 价格 | 免费额度 / 试用 |
# | :--- | :--- | :--- | :--- |
# | **Codex** | 集成于 JetBrains IDE  | 通过 OpenAI 账号、JetBrains AI 订阅等方式访问  | **限时免费**，每位用户有促销额度，用完后消耗 AI Credits 。另可获赠 **$10 测试余额** 。 |
# | **claudecode** | [anthropic.com/claude-code](https://www.anthropic.com/claude-code) (推断) | 需要 Claude Pro ($20/月) 或 Max 订阅，或使用 API 按量付费 。 | 部分第三方平台提供 **$100+ API 额度** 。GitHub Copilot 提供 **30天免费试用** (集成 Claude 3.7) 。 |
# | **opencode** | [opencode.ai](https://opencode.ai)  | **开源免费** (需自备 API 密钥) 。官方提供 OpenCode Zen 服务 。 | 自身免费，但调用 Claude、GPT 等第三方模型需自备 API 密钥并支付相应费用 。 |
# | **Qcode** | 疑似指阿里 `@qwen-code/qwen-code` CLI 工具，无独立官网  | 通过 npm 安装的命令行工具，调用阿里 Qwen 模型需支付 API 费用 。 | 工具本身免费，但调用阿里 Qwen Coder 等模型需按 API 使用量付费 。 |
# | **CodeBuddy** | [codebuddy.ai](https://www.codebuddy.ai)  | **Pro 月付**: $9.95/月<br>**Pro 年付**: $119.4/年  | **免费版**: 250 积分 / 2 周 。 |
# | **Cursor** | [cursor.com](https://www.cursor.com)  | **Pro 版**: $20/月 。 | **Hobby 免费版**: Premium 请求 50次/月，代码补全 2000次/月 。**新用户**: 14天 Pro 试用 (含150次快速请求) 。**学生**: 可申请免费 Pro 一年 。 |
# | **trae 国内版** | [trae.com.cn](https://www.trae.com.cn)  | **完全免费** 。 | 全部功能免费，支持豆包和 DeepSeek 模型 。 |
# | **trae 国际版** | [trae.ai](https://www.trae.ai)  | **Pro 版**: $10/月 。 | **免费版**: 超级模型快速队列 10次/月，高级模型 1000次/月 。**Pro 版**: 超级模型快速队列 600次/月，慢速队列和高级模型无限制 。 |
# | **Antigravity IDE** | [antigravity-ide.com](https://www.antigravity-ide.com)  | **公开预览阶段免费** 。 | 完全免费，由 Google 账号登录即可使用，Gemini 3 Pro 模型配额每5小时刷新，足够个人使用 。 |

# %% [markdown]
# 以下是 **Antigravity、Claude Code、Cursor、Trae 国内版、Trae 国际版** 的免费/付费额度与价格对比（2026-03-01，汇率：1 USD ≈ 6.92 CNY）。
#
# | 工具 | 版本 | 价格（月） | 免费额度 | 付费核心额度 | 计费/刷新机制 |
# |---|---|---|---|---|---|
# | **Antigravity IDE** | 免费版 | $0 | 全功能，**每周刷新**配额 | - | 每周重置，密集用约 2–3 小时触顶 |
# | | Google AI Pro | $19.99（≈138 元） | - | 每 5 小时刷新，配额更高 | 每 5 小时重置 |
# | | Google AI Ultra | $249.99（≈1729 元） | - | 每 5 小时刷新，最高配额 | 每 5 小时重置 |
# | **Claude Code** | 免费版 | $0 | 无独立免费，需订阅 Claude 套餐 | - | 订阅制，额度随套餐 |
# | | Claude Pro | $20（≈138 元） | - | 每 5 小时滚动额度，约 550 万 credits | 每 5 小时重置 |
# | | Claude Max 5x | $100（≈692 元） | - | 每 5 小时约 330 万 credits，周上限 4166 万 | 每 5 小时+周上限 |
# | | Claude Max 20x | $200（≈1384 元） | - | 每 5 小时约 1100 万 credits，周上限 8333 万 | 每 5 小时+周上限 |
# | | API 按量 | 输入 $3–5/M，输出 $15–25/M | - | 按 Token 计费，无固定额度 | 实时计费 |
# | **Cursor** | 免费版 | $0 | 每月 **2000 次代码补全 + 50 次慢速 AI 调用** | - | 每月重置 |
# | | Pro 版 | $20（≈138 元） | - | **无限 AI 调用**，优先模型（GPT-4/Claude 3.7） | 无限制 |
# | | 团队版 | $40/人（≈277 元） | - | 无限调用 + 协作/管理功能 | 无限制 |
# | **Trae 国内版** | 免费版 | $0 | **全功能永久免费**（国内模型） | - | 无限，高峰可能排队 |
# | | 企业版 | 定制 | - | 500 次/月/席位 AI 对话，代码补全无限 | 每月重置 |
# | **Trae 国际版** | Free | $0 | 基础模型免费，**按 Token 计费** | - | 免费额度有限，用完即止 |
# | | Lite | $3（≈20.7 元） | - | 基础 Token 额度，轻度使用 | 每月重置 |
# | | Pro | $10（≈69.2 元） | - | 更多 Token，支持 SOLO Builder | 每月重置 |
# | | Pro+ | $30（≈207.5 元） | - | 高 Token 额度，优先响应 | 每月重置 |
# | | Ultra | $100（≈691.6 元） | - | 最高 Token 额度，企业级 | 每月重置 |
#
# 1. **免费友好度**
#    - **Trae 国内版**：唯一**永久全免费**，国内模型无限制，适合中文开发者零成本入门。
#    - **Antigravity**：免费版全功能开放，仅**每周刷新配额**，适合学习与轻度开发。
#    - **Cursor**：免费版有明确限额（2000 补全+50 调用），适合尝鲜。
#    - **Claude Code**：无独立免费，必须订阅 Claude 套餐。
#
# 2. **付费性价比（个人开发者）**
#    - **Cursor Pro**：$20/月，**无限调用**，模型强、生态成熟，专业开发首选。
#    - **Trae 国际版 Pro**：$10/月，Token 额度够用，支持国际模型，性价比高。
#    - **Claude Pro**：$20/月，适合重度依赖 Claude 长上下文与推理的场景。
#    - **Antigravity Pro**：$19.99/月，适合重度使用 Google 生态模型的开发者。
#
# 3. **计费方式**
#    - **订阅制（固定额度）**：Antigravity、Claude Code、Cursor、Trae 国际版（Lite/Pro/Pro+/Ultra），适合稳定使用、预算可控。
#    - **按量计费（Token）**：Claude Code API、Trae 国际版 Free，适合偶尔使用、灵活控制成本。
#    - **完全免费**：Trae 国内版，无任何额度限制（仅高峰排队）。
#
# - 纯中文开发、零成本：**Trae 国内版**
# - 国际模型、轻度免费：**Antigravity 免费版**
# - 专业开发、无限调用：**Cursor Pro**
# - 性价比、国际模型：**Trae 国际版 Pro**
# - 重度 Claude 依赖：**Claude Pro/Max**
